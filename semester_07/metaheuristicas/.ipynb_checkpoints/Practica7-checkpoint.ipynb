# %% [markdown]
# ## Práctica 6 PSO

# %% [markdown]
# #### Paso 1
#
# Importar las librerias necesarias

# %%
from pyswarms import pso

# %%
def objective_function_(x, y):
    return (x**2) + (y**2)

# %% [markdown]
# ##### Paso 6
# Inicializamos los parametros de la PSO

# %%
num_particles = 30
num_dimensions = 1
num_iterations = 100
w = 0.5
c1 = 1.5
c2 = 2.0

# Limites de la busqueda
bounds = (-10, 10)

# %% [markdown]
# ##### Paso 7
# Inicializamos las particulas y sus velocidades

# %%
particles = np.random.uniform(bounds[0], bounds[1], (num_particles, num_dimensions))
velocities = np.random.uniform(-1, 1, (num_particles, num_dimensions))

p_best_position = particles.copy()
p_best_value = np.array([objective_function_(x) for x in particles])
g_best_position = p_best_position[np.argmin(p_best_value)]
g_best_value = np.min(p_best_value)

history_positions = []

# %% [markdown]
# ##### Paso 8
# Implementar el bucle principal del algoritmo

# %%
for t in range(num_iterations):
    for i in range(num_particles):
        fitness = objective_function_(particles[i])

        # Actualizar la mejor pos individual
        if fitness > p_best_value[i]:
            p_best_value[i] = fitness
            p_best_position[i] = particles[i].copy()

        # Actualizar la mejor pos global
        if fitness > g_best_value:
            g_best_value = fitness
            g_best_position = particles[i].copy()

    # Actualizar velocidades y posiciones
    for i in range(num_particles):
        r1 = random.random()
        r2 = random.random()

        velocities[i] = (w * velocities[i]
                         + c1 * r1 * (p_best_position[i] - particles[i])
                         + c2 * r2 * (g_best_position - particles[i]))

        particles[i] = particles[i] + velocities[i]

        # Respetar los limites de la busqueda
        particles[i] = np.clip(particles[i], bounds[0], bounds[1])

    history_positions.append(particles.copy())
    print(f'Iteracion: {t+1}/{num_iterations}, Mejor valor global: {g_best_value}')

print(f'Mejor posicion encontrada: {g_best_position}, con valor: {g_best_value}')
# Out:
# Iteracion: 1/100, Mejor valor global: [-6395.3120118]
# Iteracion: 2/100, Mejor valor global: [-6196.4315355]
# Iteracion: 3/100, Mejor valor global: [-5599.68772545]
# Iteracion: 4/100, Mejor valor global: [-4161.43348119]
# Iteracion: 5/100, Mejor valor global: [-1082.9486865]
# Iteracion: 6/100, Mejor valor global: [0.63951889]
# Iteracion: 7/100, Mejor valor global: [0.63951889]
# Iteracion: 8/100, Mejor valor global: [1.95783021]
# Iteracion: 9/100, Mejor valor global: [1.95783021]
# Iteracion: 10/100, Mejor valor global: [1.96218786]
# Iteracion: 11/100, Mejor valor global: [1.96218786]
# Iteracion: 12/100, Mejor valor global: [1.96218786]
# Iteracion: 13/100, Mejor valor global: [1.96218786]
# Iteracion: 14/100, Mejor valor global: [1.99976989]
# Iteracion: 15/100, Mejor valor global: [1.99976989]
# Iteracion: 16/100, Mejor valor global: [1.99976989]
# Iteracion: 17/100, Mejor valor global: [1.99976989]
# Iteracion: 18/100, Mejor valor global: [1.99976989]
# Iteracion: 19/100, Mejor valor global: [1.99976989]
# Iteracion: 20/100, Mejor valor global: [1.99976989]
# Iteracion: 21/100, Mejor valor global: [1.99976989]
# Iteracion: 22/100, Mejor valor global: [1.99976989]
# Iteracion: 23/100, Mejor valor global: [1.99996947]
# Iteracion: 24/100, Mejor valor global: [1.99996947]
# Iteracion: 25/100, Mejor valor global: [1.99996947]
# Iteracion: 26/100, Mejor valor global: [1.99997435]
# Iteracion: 27/100, Mejor valor global: [1.99999767]
# Iteracion: 28/100, Mejor valor global: [1.99999767]
# Iteracion: 29/100, Mejor valor global: [1.99999941]
# Iteracion: 30/100, Mejor valor global: [1.99999943]
# Iteracion: 31/100, Mejor valor global: [1.99999972]
# Iteracion: 32/100, Mejor valor global: [1.99999996]
# Iteracion: 33/100, Mejor valor global: [1.99999996]
# Iteracion: 34/100, Mejor valor global: [1.99999996]
# Iteracion: 35/100, Mejor valor global: [1.99999997]
# Iteracion: 36/100, Mejor valor global: [1.99999997]
# Iteracion: 37/100, Mejor valor global: [1.99999999]
# Iteracion: 38/100, Mejor valor global: [2.]
# Iteracion: 39/100, Mejor valor global: [2.]
# Iteracion: 40/100, Mejor valor global: [2.]
# Iteracion: 41/100, Mejor valor global: [2.]
# Iteracion: 42/100, Mejor valor global: [2.]
# Iteracion: 43/100, Mejor valor global: [2.]
# Iteracion: 44/100, Mejor valor global: [2.]
# Iteracion: 45/100, Mejor valor global: [2.]
# Iteracion: 46/100, Mejor valor global: [2.]
# Iteracion: 47/100, Mejor valor global: [2.]
# Iteracion: 48/100, Mejor valor global: [2.]
# Iteracion: 49/100, Mejor valor global: [2.]
# Iteracion: 50/100, Mejor valor global: [2.]
# Iteracion: 51/100, Mejor valor global: [2.]
# Iteracion: 52/100, Mejor valor global: [2.]
# Iteracion: 53/100, Mejor valor global: [2.]
# Iteracion: 54/100, Mejor valor global: [2.]
# Iteracion: 55/100, Mejor valor global: [2.]
# Iteracion: 56/100, Mejor valor global: [2.]
# Iteracion: 57/100, Mejor valor global: [2.]
# Iteracion: 58/100, Mejor valor global: [2.]
# Iteracion: 59/100, Mejor valor global: [2.]
# Iteracion: 60/100, Mejor valor global: [2.]
# Iteracion: 61/100, Mejor valor global: [2.]
# Iteracion: 62/100, Mejor valor global: [2.]
# Iteracion: 63/100, Mejor valor global: [2.]
# Iteracion: 64/100, Mejor valor global: [2.]
# Iteracion: 65/100, Mejor valor global: [2.]
# Iteracion: 66/100, Mejor valor global: [2.]
# Iteracion: 67/100, Mejor valor global: [2.]
# Iteracion: 68/100, Mejor valor global: [2.]
# Iteracion: 69/100, Mejor valor global: [2.]
# Iteracion: 70/100, Mejor valor global: [2.]
# Iteracion: 71/100, Mejor valor global: [2.]
# Iteracion: 72/100, Mejor valor global: [2.]
# Iteracion: 73/100, Mejor valor global: [2.]
# Iteracion: 74/100, Mejor valor global: [2.]
# Iteracion: 75/100, Mejor valor global: [2.]
# Iteracion: 76/100, Mejor valor global: [2.]
# Iteracion: 77/100, Mejor valor global: [2.]
# Iteracion: 78/100, Mejor valor global: [2.]
# Iteracion: 79/100, Mejor valor global: [2.]
# Iteracion: 80/100, Mejor valor global: [2.]
# Iteracion: 81/100, Mejor valor global: [2.]
# Iteracion: 82/100, Mejor valor global: [2.]
# Iteracion: 83/100, Mejor valor global: [2.]
# Iteracion: 84/100, Mejor valor global: [2.]
# Iteracion: 85/100, Mejor valor global: [2.]
# Iteracion: 86/100, Mejor valor global: [2.]
# Iteracion: 87/100, Mejor valor global: [2.]
# Iteracion: 88/100, Mejor valor global: [2.]
# Iteracion: 89/100, Mejor valor global: [2.]
# Iteracion: 90/100, Mejor valor global: [2.]
# Iteracion: 91/100, Mejor valor global: [2.]
# Iteracion: 92/100, Mejor valor global: [2.]
# Iteracion: 93/100, Mejor valor global: [2.]
# Iteracion: 94/100, Mejor valor global: [2.]
# Iteracion: 95/100, Mejor valor global: [2.]
# Iteracion: 96/100, Mejor valor global: [2.]
# Iteracion: 97/100, Mejor valor global: [2.]
# Iteracion: 98/100, Mejor valor global: [2.]
# Iteracion: 99/100, Mejor valor global: [2.]
# Iteracion: 100/100, Mejor valor global: [2.]
# Mejor posicion encontrada: [-9.07401365], con valor: [2.]

# %% [markdown]
# #### Paso 9, graficamos

# %%
x_values = np.linspace(-10, 10, 400)
y_values = objective_function_(x_values)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label="f(x) = x^2")

plt.scatter([g_best_position], [objective_function_(g_best_position)], color="blue", marker="x", s=100, label="Mejor posicion")

for positions in history_positions:
    plt.scatter(positions, objective_function_(positions), color="red", alpha=0.2)

# %% [markdown]
# ### Conclusiones
#
# El PSO es un algoritmo de uptimización basado en la simulación de la conducta social de organismos, como bancos de peces. En esta práctica implementamos PSO para buscar el óptimo global (en el primer ejemplo buscando el mínimo y en el segundo ejemplo el máximo) de una función en 2D
